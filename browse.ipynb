# %%
import pandas as pd
from pathlib import Path

CSV = Path("nhk_bsp4k_movies.csv")
df = pd.read_csv(CSV)

META_COLS = ["broadcast_date", "broadcast_time", "program_name", "title"]

# %%
concerned_services = ["Netflix", "Amazon Prime Video", "Disney+", "Apple TV"]
mask = ~df[concerned_services].any(axis=1)
filtered = df.loc[mask, META_COLS + concerned_services]
filteredroadcasting schedule
# Out:
#   broadcast_date broadcast_time program_name           title  Netflix  \
# 2     2026-03-17          09:30        シネマ4K  山椒大夫 4Kデジタル修復版    False
# 5     2026-03-20          09:30        シネマ4K  復活の日 4Kデジタル修復版    False
#
#    Amazon Prime Video  Disney+  Apple TV
# 2               False    False     False
# 5               False    False     False
